# %%
import numpy as np
array=np.array([1,2,3])
print(array)
print(type(array));
print(array.shape)
# Out:
# [1 2 3]
# <class 'numpy.ndarray'>
# (3,)

# %%
print(array[2])
# Out:
# 3

# %%
print(array[0])
# Out:
# np.int64(1)

# %%
array[2]=5
array
# Out:
# array([1, 2, 5])

# %%
array2=np.array([[1,2,3],[3,4,5]])
array2
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])

# %%
print(array2[1][2])
print(array2.shape)
# Out:
# 5
# (2, 3)

# %%
array2[1,2]
# Out:
# np.int64(5)

# %%
array2[1,-2]
# Out:
# np.int64(4)

# %%
arr2=np.array(['china', 'pakistan', 'india'])
print(arr2)
# Out:
# ['china' 'pakistan' 'india']

# %%
arr3=np.arange(9,20)
arr3
# Out:
# array([0])

# %%
arr5=np.arange(0,20,2)
arr5
arr5=np.linspace(0,10,20)
arr5
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
rk=np.random.rand(10)
rk
# Out:
# array([0.49711944, 0.42147107, 0.25679144, 0.12138046, 0.60426296,
#        0.11192975, 0.06726412, 0.32289687, 0.49346742, 0.34274144])

# %%
rohit=np.random.rand(3,4)
rohit
# Out:
# array([[0.11847294, 0.83451286, 0.89824352, 0.116071  ],
#        [0.43240609, 0.88350206, 0.03926437, 0.44502761],
#        [0.91182211, 0.23428409, 0.03408624, 0.9356012 ]])

# %%
rohit1=np.random.rand()
rohit1
# Out:
# 0.8463707759101547

# %%
arr1=np.array([1,2,3,4,5])
arr2=np.array([4,5,6,7,8])
np.intersect1d(arr1,arr2)
# Out:
# array([4, 5])
